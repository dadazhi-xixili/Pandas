# %% [markdown]
# # style.apply
# ## 说明
# 根据`func`参数传入相同长度列表文本对行或列应用样式
# ## 参数
# * `func`：文本矩阵应用样式函数。
#     - 返回对象长度需要和原对象长度一致。
# * `axis`：应用样式轴。
#     - 1：行。
#     - 0：列。
# * `level`：多级索引。
# * `subset`: 子集。
# * `可变参数`: `func`中定义的变量可以传入。

# %%
import pandas as pd
import numpy as np

df = pd.read_csv(
    filepath_or_buffer = r'..\0-data\beijing_tianqi\beijing_tianqi_2018.csv',
    sep = ',',
    usecols = range(8),
    nrows = 20,
    skiprows = 1,
    header = None,
    names = [
        '日期', '最高温度', '最低温度',
        '天气', '风向', '风速',
        '空气指数', '空气质量', '空气质量等级',
    ],
    dtype = {'空气指数': 'int8', '空气质量等级': 'int8'},
    parse_dates = ['日期'],
    date_format = '%Y-%m-%d',
    encoding = 'utf-8',
    index_col = '日期',
    converters = {'最高温度': lambda x: int(x[:-1]), '最低温度': lambda x : int(x[:-1])},
)
df.head()
# Out:
#             最高温度  最低温度    天气   风向    风速  空气指数 空气质量
# 日期
# 2018-01-01     3    -6  晴~多云  东北风  1-2级    59    良
# 2018-01-02     2    -5  阴~多云  东北风  1-2级    49    优
# 2018-01-03     2    -5    多云   北风  1-2级    28    优
# 2018-01-04     0    -8     阴  东北风  1-2级    28    优
# 2018-01-05     3    -6  多云~晴  西北风  1-2级    50    优

# %%
df.style.apply(
    func=lambda x, T_color, F_color, T_text_color, F_text_color: np.where(
        x > 0,
        f'color: {T_text_color};background-color: {T_color};font-family: 宋体',
        f'color: {F_text_color};background-color: {F_color};font-family: 微软雅黑',
    ),
    T_color='OrangeRed',
    F_color='PaleTurquoise',
    T_text_color='rgb(255,255,255)',
    F_text_color='#000000',
    subset=['最高温度', '最低温度'],
)
# Out:
# <style type="text/css">
# #T_f80d5_row0_col0, #T_f80d5_row1_col0, #T_f80d5_row2_col0, #T_f80d5_row4_col0, #T_f80d5_row5_col0, #T_f80d5_row6_col0, #T_f80d5_row7_col0, #T_f80d5_row8_col0, #T_f80d5_row11_col0, #T_f80d5_row12_col0, #T_f80d5_row13_col0, #T_f80d5_row14_col0, #T_f80d5_row15_col0, #T_f80d5_row16_col0, #T_f80d5_row17_col0, #T_f80d5_row18_col0, #T_f80d5_row19_col0 {
#   color: rgb(255,255,255);
#   background-color: OrangeRed;
#   font-family: 宋体;
# }
# #T_f80d5_row0_col1, #T_f80d5_row1_col1, #T_f80d5_row2_col1, #T_f80d5_row3_col0, #T_f80d5_row3_col1, #T_f80d5_row4_col1, #T_f80d5_row5_col1, #T_f80d5_row6_col1, #T_f80d5_row7_col1, #T_f80d5_row8_col1, #T_f80d5_row9_col0, #T_f80d5_row9_col1, #T_f80d5_row10_col0, #T_f80d5_row10_col1, #T_f80d5_row11_col1, #T_f80d5_row12_col1, #T_f80d5_row13_col1, #T_f80d5_row14_col1, #T_f80d5_row15_col1, #T_f80d5_row16_col1, #T_f80d5_row17_col1, #T_f80d5_row18_col1, #T_f80d5_row19_col1 {
#   color: #000000;
#   background-color: PaleTurquoise;
#   font-family: 微软雅黑;
# }
# </style>
# <table id="T_f80d5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f80d5_level0_col0" class="col_heading level0 col0" >最高温度</th>
#       <th id="T_f80d5_level0_col1" class="col_heading level0 col1" >最低温度</th>
#       <th id="T_f80d5_level0_col2" class="col_heading level0 col2" >天气</th>
#       <th id="T_f80d5_level0_col3" class="col_heading level0 col3" >风向</th>
#       <th id="T_f80d5_level0_col4" class="col_heading level0 col4" >风速</th>
#       <th id="T_f80d5_level0_col5" class="col_heading level0 col5" >空气指数</th>
#       <th id="T_f80d5_level0_col6" class="col_heading level0 col6" >空气质量</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >日期</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f80d5_level0_row0" class="row_heading level0 row0" >2018-01-01 00:00:00</th>
#       <td id="T_f80d5_row0_col0" class="data row0 col0" >3</td>
#       <td id="T_f80d5_row0_col1" class="data row0 col1" >-6</td>
#       <td id="T_f80d5_row0_col2" class="data row0 col2" >晴~多云</td>
#       <td id="T_f80d5_row0_col3" class="data row0 col3" >东北风</td>
#       <td id="T_f80d5_row0_col4" class="data row0 col4" >1-2级</td>
#       <td id="T_f80d5_row0_col5" class="data row0 col5" >59</td>
#       <td id="T_f80d5_row0_col6" class="data row0 col6" >良</td>
#     </tr>
#     <tr>
#       <th id="T_f80d5_level0_row1" class="row_heading level0 row1" >2018-01-02 00:00:00</th>
#       <td id="T_f80d5_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_f80d5_row1_col1" class="data row1 col1" >-5</td>
#       <td id="T_f80d5_row1_col2" class="data row1 col2" >阴~多云</td>
#       <td id="T_f80d5_row1_col3" class="data row1 col3" >东北风</td>
#       <td id="T_f80d5_row1_col4" class="data row1 col4" >1-2级</td>
#       <td id="T_f80d5_row1_col5" class="data row1 col5" >49</td>
#       <td id="T_f80d5_row1_col6" class="data row1 col6" >优</td>
#     </tr>
#     <tr>
#       <th id="T_f80d5_level0_row2" class="row_heading level0 row2" >2018-01-03 00:00:00</th>
#       <td id="T_f80d5_row2_col0" class="data row2 col0" >2</td>
#       <td id="T_f80d5_row2_col1" class="data row2 col1" >-5</td>
#       <td id="T_f80d5_row2_col2" class="data row2 col2" >多云</td>
#       <td id="T_f80d5_row2_col3" class="data row2 col3" >北风</td>
#       <td id="T_f80d5_row2_col4" class="data row2 col4" >1-2级</td>
#       <td id="T_f80d5_row2_col5" class="data row2 col5" >28</td>
#       <td id="T_f80d5_row2_col6" class="data row2 col6" >优</td>
#     </tr>
#     <tr>
#       <th id="T_f80d5_level0_row3" class="row_heading level0 row3" >2018-01-04 00:00:00</th>
#       <td id="T_f80d5_row3_col0" class="data row3 col0" >0</td>
#       <td id="T_f80d5_row3_col1" class="data row3 col1" >-8</td>
#       <td id="T_f80d5_row3_col2" class="data row3 col2" >阴</td>
#       <td id="T_f80d5_row3_col3" class="data row3 col3" >东北风</td>
#       <td id="T_f80d5_row3_col4" class="data row3 col4" >1-2级</td>
#       <td id="T_f80d5_row3_col5" class="data row3 col5" >28</td>
#       <td id="T_f80d5_row3_col6" class="data row3 col6" >优</td>
#     </tr>
#     <tr>
#       <th id="T_f80d5_level0_row4" class="row_heading level0 row4" >2018-01-05 00:00:00</th>
#       <td id="T_f80d5_row4_col0" class="data row4 col0" >3</td>
#       <td id="T_f80d5_row4_col1" class="data row4 col1" >-6</td>
#       <td id="T_f80d5_row4_col2" class="data row4 col2" >多云~晴</td>
#       <td id="T_f80d5_row4_col3" class="data row4 col3" >西北风</td>
#       <td id="T_f80d5_row4_col4" class="data row4 col4" >1-2级</td>
#       <td id="T_f80d5_row4_col5" class="data row4 col5" >50</td>
#       <td id="T_f80d5_row4_col6" class="data row4 col6" >优</td>
#     </tr>
#     <tr>
#       <th id="T_f80d5_level0_row5" class="row_heading level0 row5" >2018-01-06 00:00:00</th>
#       <td id="T_f80d5_row5_col0" class="data row5 col0" >2</td>
#       <td id="T_f80d5_row5_col1" class="data row5 col1" >-5</td>
#       <td id="T_f80d5_row5_col2" class="data row5 col2" >多云~阴</td>
#       <td id="T_f80d5_row5_col3" class="data row5 col3" >西南风</td>
#       <td id="T_f80d5_row5_col4" class="data row5 col4" >1-2级</td>
#       <td id="T_f80d5_row5_col5" class="data row5 col5" >32</td>
#       <td id="T_f80d5_row5_col6" class="data row5 col6" >优</td>
#     </tr>
#     <tr>
#       <th id="T_f80d5_level0_row6" class="row_heading level0 row6" >2018-01-07 00:00:00</th>
#       <td id="T_f80d5_row6_col0" class="data row6 col0" >2</td>
#       <td id="T_f80d5_row6_col1" class="data row6 col1" >-4</td>
#       <td id="T_f80d5_row6_col2" class="data row6 col2" >阴~多云</td>
#       <td id="T_f80d5_row6_col3" class="data row6 col3" >西南风</td>
#       <td id="T_f80d5_row6_col4" class="data row6 col4" >1-2级</td>
#       <td id="T_f80d5_row6_col5" class="data row6 col5" >59</td>
#       <td id="T_f80d5_row6_col6" class="data row6 col6" >良</td>
#     </tr>
#     <tr>
#       <th id="T_f80d5_level0_row7" class="row_heading level0 row7" >2018-01-08 00:00:00</th>
#       <td id="T_f80d5_row7_col0" class="data row7 col0" >2</td>
#       <td id="T_f80d5_row7_col1" class="data row7 col1" >-6</td>
#       <td id="T_f80d5_row7_col2" class="data row7 col2" >晴</td>
#       <td id="T_f80d5_row7_col3" class="data row7 col3" >西北风</td>
#       <td id="T_f80d5_row7_col4" class="data row7 col4" >4-5级</td>
#       <td id="T_f80d5_row7_col5" class="data row7 col5" >50</td>
#       <td id="T_f80d5_row7_col6" class="data row7 col6" >优</td>
#     </tr>
#     <tr>
#       <th id="T_f80d5_level0_row8" class="row_heading level0 row8" >2018-01-09 00:00:00</th>
#       <td id="T_f80d5_row8_col0" class="data row8 col0" >1</td>
#       <td id="T_f80d5_row8_col1" class="data row8 col1" >-8</td>
#       <td id="T_f80d5_row8_col2" class="data row8 col2" >晴</td>
#       <td id="T_f80d5_row8_col3" class="data row8 col3" >西北风</td>
#       <td id="T_f80d5_row8_col4" class="data row8 col4" >3-4级</td>
#       <td id="T_f80d5_row8_col5" class="data row8 col5" >34</td>
#       <td id="T_f80d5_row8_col6" class="data row8 col6" >优</td>
#     </tr>
#     <tr>
#       <th id="T_f80d5_level0_row9" class="row_heading level0 row9" >2018-01-10 00:00:00</th>
#       <td id="T_f80d5_row9_col0" class="data row9 col0" >-2</td>
#       <td id="T_f80d5_row9_col1" class="data row9 col1" >-10</td>
#       <td id="T_f80d5_row9_col2" class="data row9 col2" >晴</td>
#       <td id="T_f80d5_row9_col3" class="data row9 col3" >西北风</td>
#       <td id="T_f80d5_row9_col4" class="data row9 col4" >1-2级</td>
#       <td id="T_f80d5_row9_col5" class="data row9 col5" >26</td>
#       <td id="T_f80d5_row9_col6" class="data row9 col6" >优</td>
#     </tr>
#     <tr>
#       <th id="T_f80d5_level0_row10" class="row_heading level0 row10" >2018-01-11 00:00:00</th>
#       <td id="T_f80d5_row10_col0" class="data row10 col0" >-1</td>
#       <td id="T_f80d5_row10_col1" class="data row10 col1" >-10</td>
#       <td id="T_f80d5_row10_col2" class="data row10

# %%
df.style.apply(
    lambda x:['text-align: justify;font-family: 微软雅黑']*len(x),
    subset='风向'
)
# Out:
# <style type="text/css">
# #T_556f6_row0_col3, #T_556f6_row1_col3, #T_556f6_row2_col3, #T_556f6_row3_col3, #T_556f6_row4_col3, #T_556f6_row5_col3, #T_556f6_row6_col3, #T_556f6_row7_col3, #T_556f6_row8_col3, #T_556f6_row9_col3, #T_556f6_row10_col3, #T_556f6_row11_col3, #T_556f6_row12_col3, #T_556f6_row13_col3, #T_556f6_row14_col3, #T_556f6_row15_col3, #T_556f6_row16_col3, #T_556f6_row17_col3, #T_556f6_row18_col3, #T_556f6_row19_col3 {
#   text-align: justify;
#   font-family: 微软雅黑;
# }
# </style>
# <table id="T_556f6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_556f6_level0_col0" class="col_heading level0 col0" >最高温度</th>
#       <th id="T_556f6_level0_col1" class="col_heading level0 col1" >最低温度</th>
#       <th id="T_556f6_level0_col2" class="col_heading level0 col2" >天气</th>
#       <th id="T_556f6_level0_col3" class="col_heading level0 col3" >风向</th>
#       <th id="T_556f6_level0_col4" class="col_heading level0 col4" >风速</th>
#       <th id="T_556f6_level0_col5" class="col_heading level0 col5" >空气指数</th>
#       <th id="T_556f6_level0_col6" class="col_heading level0 col6" >空气质量</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >日期</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_556f6_level0_row0" class="row_heading level0 row0" >2018-01-01 00:00:00</th>
#       <td id="T_556f6_row0_col0" class="data row0 col0" >3</td>
#       <td id="T_556f6_row0_col1" class="data row0 col1" >-6</td>
#       <td id="T_556f6_row0_col2" class="data row0 col2" >晴~多云</td>
#       <td id="T_556f6_row0_col3" class="data row0 col3" >东北风</td>
#       <td id="T_556f6_row0_col4" class="data row0 col4" >1-2级</td>
#       <td id="T_556f6_row0_col5" class="data row0 col5" >59</td>
#       <td id="T_556f6_row0_col6" class="data row0 col6" >良</td>
#     </tr>
#     <tr>
#       <th id="T_556f6_level0_row1" class="row_heading level0 row1" >2018-01-02 00:00:00</th>
#       <td id="T_556f6_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_556f6_row1_col1" class="data row1 col1" >-5</td>
#       <td id="T_556f6_row1_col2" class="data row1 col2" >阴~多云</td>
#       <td id="T_556f6_row1_col3" class="data row1 col3" >东北风</td>
#       <td id="T_556f6_row1_col4" class="data row1 col4" >1-2级</td>
#       <td id="T_556f6_row1_col5" class="data row1 col5" >49</td>
#       <td id="T_556f6_row1_col6" class="data row1 col6" >优</td>
#     </tr>
#     <tr>
#       <th id="T_556f6_level0_row2" class="row_heading level0 row2" >2018-01-03 00:00:00</th>
#       <td id="T_556f6_row2_col0" class="data row2 col0" >2</td>
#       <td id="T_556f6_row2_col1" class="data row2 col1" >-5</td>
#       <td id="T_556f6_row2_col2" class="data row2 col2" >多云</td>
#       <td id="T_556f6_row2_col3" class="data row2 col3" >北风</td>
#       <td id="T_556f6_row2_col4" class="data row2 col4" >1-2级</td>
#       <td id="T_556f6_row2_col5" class="data row2 col5" >28</td>
#       <td id="T_556f6_row2_col6" class="data row2 col6" >优</td>
#     </tr>
#     <tr>
#       <th id="T_556f6_level0_row3" class="row_heading level0 row3" >2018-01-04 00:00:00</th>
#       <td id="T_556f6_row3_col0" class="data row3 col0" >0</td>
#       <td id="T_556f6_row3_col1" class="data row3 col1" >-8</td>
#       <td id="T_556f6_row3_col2" class="data row3 col2" >阴</td>
#       <td id="T_556f6_row3_col3" class="data row3 col3" >东北风</td>
#       <td id="T_556f6_row3_col4" class="data row3 col4" >1-2级</td>
#       <td id="T_556f6_row3_col5" class="data row3 col5" >28</td>
#       <td id="T_556f6_row3_col6" class="data row3 col6" >优</td>
#     </tr>
#     <tr>
#       <th id="T_556f6_level0_row4" class="row_heading level0 row4" >2018-01-05 00:00:00</th>
#       <td id="T_556f6_row4_col0" class="data row4 col0" >3</td>
#       <td id="T_556f6_row4_col1" class="data row4 col1" >-6</td>
#       <td id="T_556f6_row4_col2" class="data row4 col2" >多云~晴</td>
#       <td id="T_556f6_row4_col3" class="data row4 col3" >西北风</td>
#       <td id="T_556f6_row4_col4" class="data row4 col4" >1-2级</td>
#       <td id="T_556f6_row4_col5" class="data row4 col5" >50</td>
#       <td id="T_556f6_row4_col6" class="data row4 col6" >优</td>
#     </tr>
#     <tr>
#       <th id="T_556f6_level0_row5" class="row_heading level0 row5" >2018-01-06 00:00:00</th>
#       <td id="T_556f6_row5_col0" class="data row5 col0" >2</td>
#       <td id="T_556f6_row5_col1" class="data row5 col1" >-5</td>
#       <td id="T_556f6_row5_col2" class="data row5 col2" >多云~阴</td>
#       <td id="T_556f6_row5_col3" class="data row5 col3" >西南风</td>
#       <td id="T_556f6_row5_col4" class="data row5 col4" >1-2级</td>
#       <td id="T_556f6_row5_col5" class="data row5 col5" >32</td>
#       <td id="T_556f6_row5_col6" class="data row5 col6" >优</td>
#     </tr>
#     <tr>
#       <th id="T_556f6_level0_row6" class="row_heading level0 row6" >2018-01-07 00:00:00</th>
#       <td id="T_556f6_row6_col0" class="data row6 col0" >2</td>
#       <td id="T_556f6_row6_col1" class="data row6 col1" >-4</td>
#       <td id="T_556f6_row6_col2" class="data row6 col2" >阴~多云</td>
#       <td id="T_556f6_row6_col3" class="data row6 col3" >西南风</td>
#       <td id="T_556f6_row6_col4" class="data row6 col4" >1-2级</td>
#       <td id="T_556f6_row6_col5" class="data row6 col5" >59</td>
#       <td id="T_556f6_row6_col6" class="data row6 col6" >良</td>
#     </tr>
#     <tr>
#       <th id="T_556f6_level0_row7" class="row_heading level0 row7" >2018-01-08 00:00:00</th>
#       <td id="T_556f6_row7_col0" class="data row7 col0" >2</td>
#       <td id="T_556f6_row7_col1" class="data row7 col1" >-6</td>
#       <td id="T_556f6_row7_col2" class="data row7 col2" >晴</td>
#       <td id="T_556f6_row7_col3" class="data row7 col3" >西北风</td>
#       <td id="T_556f6_row7_col4" class="data row7 col4" >4-5级</td>
#       <td id="T_556f6_row7_col5" class="data row7 col5" >50</td>
#       <td id="T_556f6_row7_col6" class="data row7 col6" >优</td>
#     </tr>
#     <tr>
#       <th id="T_556f6_level0_row8" class="row_heading level0 row8" >2018-01-09 00:00:00</th>
#       <td id="T_556f6_row8_col0" class="data row8 col0" >1</td>
#       <td id="T_556f6_row8_col1" class="data row8 col1" >-8</td>
#       <td id="T_556f6_row8_col2" class="data row8 col2" >晴</td>
#       <td id="T_556f6_row8_col3" class="data row8 col3" >西北风</td>
#       <td id="T_556f6_row8_col4" class="data row8 col4" >3-4级</td>
#       <td id="T_556f6_row8_col5" class="data row8 col5" >34</td>
#       <td id="T_556f6_row8_col6" class="data row8 col6" >优</td>
#     </tr>
#     <tr>
#       <th id="T_556f6_level0_row9" class="row_heading level0 row9" >2018-01-10 00:00:00</th>
#       <td id="T_556f6_row9_col0" class="data row9 col0" >-2</td>
#       <td id="T_556f6_row9_col1" class="data row9 col1" >-10</td>
#       <td id="T_556f6_row9_col2" class="data row9 col2" >晴</td>
#       <td id="T_556f6_row9_col3" class="data row9 col3" >西北风</td>
#       <td id="T_556f6_row9_col4" class="data row9 col4" >1-2级</td>
#       <td id="T_556f6_row9_col5" class="data row9 col5" >26</td>
#       <td id="T_556f6_row9_col6" class="data row9 col6" >优</td>
#     </tr>
#     <tr>
#       <th id="T_556f6_level0_row10" class="row_heading level0 row10" >2018-01-11 00:00:00</th>
#       <td id="T_556f6_row10_col0" class="data row10 col0" >-1</td>
#       <td id="T_556f6_row10_col1" class="data row10 col1" >-10</td>
#       <td id="T_556f6_row10_col2" class="data row10 col2" >晴</td>
#       <td id="T_556f6_row10_col3" class="data row10 col3" >北风</td>
#       <td id="T_556f6_row10_col4" class="data row10 col4" >1-2级</td>
#       <td id="T_556f6_row10_col5" class="data row10 col5" >24</td>
#       <td id="T_556f6_row10_col6" class="data row10 col6" >优</td>
#     </tr>
#     <tr>
#       <th id="T_556f6_level0_row11" class="row_heading level0 row11" >2018-01-12 00:00:00</th>
#       <td id="T_556f6_row11_col0" class="data row11 col0" >2</td>
#       <td id="T_556f6_row11_col1" class="data row11 col1
